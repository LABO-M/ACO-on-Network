# %%
import sys
import os

# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display

sys.path.append(os.path.abspath("../src"))

from visuals.plots import *

# %%
alpha09 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha0.99.csv")
alpha1 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.0.csv")
alpha101 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.02.csv")
alpha103 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.03.csv")
alpha105 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.05.csv")
alpha107 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.07.csv")
alpha11 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha1.5.csv")
alpha2 = pd.read_csv("data/Zt/N100_T100K_r10_omega-1.0_alpha2.0.csv")

columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03", "alpha=1.05", "alpha=1.07", "alpha=1.1", "alpha=1.5", "alpha=2.0"]

# データフレームの結合
# 平均値のためのデータフレーム
mean_df = pd.concat([alpha09['t'], alpha09['Z'], alpha099['Z'], alpha101['Z'], alpha102['Z'], alpha103['Z'], alpha105['Z'], alpha107['Z'], alpha11['Z'], alpha15['Z'], alpha2['Z']], axis=1)
mean_df = mean_df[mean_df['t'] > 10]
mean_df.columns = columns

# display(mean_df)

# 標準偏差のためのデータフレーム
std_df = pd.concat([alpha09['t'], alpha09['std'], alpha099['std'], alpha101['std'], alpha102['std'], alpha103['std'], alpha105['std'], alpha107['std'], alpha11['std'], alpha15['std'], alpha2['std']], axis=1)
std_df = std_df[std_df['t'] > 10]
std_df.columns = columns

# 各データセットから最後の時刻の平均値と標準偏差を抽出
data = {
    'Alpha': [0.9, 0.99, 1.0, 1.01, 1.02, 1.03, 1.05, 1.07, 1.1, 1.5, 2.0],
    'Mean_Z(t)': [df['Z'].iloc[-1] for df in [alpha09, alpha099, alpha1, alpha101, alpha102, alpha103, alpha105, alpha107, alpha11, alpha15, alpha2]],
    'Std_Z(t)': [df['std'].iloc[-1] for df in [alpha09, alpha099, alpha1, alpha101, alpha102, alpha103, alpha105, alpha107, alpha11, alpha15, alpha2]]
}

# 新しいデータフレームを作成
plot_df_w_1 = pd.DataFrame(data)

# %%
alpha09 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha1.02.csv")
alpha103 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha1.03.csv")
alpha11 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha1.5.csv")
alpha2 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.99_alpha2.0.csv")

columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03", "alpha=1.1", "alpha=1.5", "alpha=2.0"]

# データフレームの結合
# 平均値のためのデータフレーム
mean_df = pd.concat([alpha09['t'], alpha09['Z'], alpha099['Z'], alpha101['Z'], alpha102['Z'], alpha103['Z'], alpha11['Z'], alpha15['Z'], alpha2['Z']], axis=1)
mean_df = mean_df[mean_df['t'] > 10]
mean_df.columns = columns

# display(mean_df)

# # 標準偏差のためのデータフレーム
# std_df = pd.concat([alpha09['t'], alpha09['std'], alpha099['std'], alpha101['std'], alpha102['std'], alpha103['std'], alpha105['std'], alpha107['std'], alpha11['std'], alpha15['std'], alpha2['std']], axis=1)
# std_df = std_df[std_df['t'] > 10]
# std_df.columns = columns

# 各データセットから最後の時刻の平均値と標準偏差を抽出
data = {
    'Alpha': [0.9, 0.99, 1.01, 1.02, 1.03, 1.1, 1.5, 2.0],
    'Mean_Z(t)': [df['Z'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]],
    'Std_Z(t)': [df['std'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]]
}

# 新しいデータフレームを作成
plot_df_w_099 = pd.DataFrame(data)

# %%
alpha09 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha1.02.csv")
alpha103 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha1.03.csv")
alpha11 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha1.5.csv")
alpha2 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.9_alpha2.0.csv")

columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03", "alpha=1.05", "alpha=1.07", "alpha=1.1", "alpha=1.5", "alpha=2.0"]

# データフレームの結合
# 平均値のためのデータフレーム
mean_df = pd.concat([alpha09['t'], alpha09['Z'], alpha099['Z'], alpha101['Z'], alpha102['Z'], alpha103['Z'], alpha105['Z'], alpha107['Z'], alpha11['Z'], alpha15['Z'], alpha2['Z']], axis=1)
mean_df = mean_df[mean_df['t'] > 10]
mean_df.columns = columns

# display(mean_df)

# 標準偏差のためのデータフレーム
std_df = pd.concat([alpha09['t'], alpha09['std'], alpha099['std'], alpha101['std'], alpha102['std'], alpha103['std'], alpha105['std'], alpha107['std'], alpha11['std'], alpha15['std'], alpha2['std']], axis=1)
std_df = std_df[std_df['t'] > 10]
std_df.columns = columns

# 各データセットから最後の時刻の平均値と標準偏差を抽出
data = {
    'Alpha': [0.9, 0.99, 1.01, 1.02, 1.03, 1.1, 1.5, 2.0],
    'Mean_Z(t)': [df['Z'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]],
    'Std_Z(t)': [df['std'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]]
}

# 新しいデータフレームを作成
plot_df_w_09 = pd.DataFrame(data)

# %%
alpha09 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha1.02.csv")
alpha103 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha1.03.csv")
alpha11 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha1.5.csv")
alpha2 = pd.read_csv("data/Zt/N100_T100K_r10_omega-0.5_alpha2.0.csv")

columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03", "alpha=1.1", "alpha=1.5", "alpha=2.0"]

# データフレームの結合
# 平均値のためのデータフレーム
mean_df = pd.concat([alpha09['t'], alpha09['Z'], alpha099['Z'], alpha101['Z'], alpha102['Z'], alpha103['Z'], alpha11['Z'], alpha15['Z'], alpha2['Z']], axis=1)
mean_df = mean_df[mean_df['t'] > 10]
mean_df.columns = columns

# display(mean_df)

# 標準偏差のためのデータフレーム
std_df = pd.concat([alpha09['t'], alpha09['std'], alpha099['std'], alpha101['std'], alpha102['std'], alpha103['std'], alpha11['std'], alpha15['std'], alpha2['std']], axis=1)
std_df = std_df[std_df['t'] > 10]
std_df.columns = columns

# 各データセットから最後の時刻の平均値と標準偏差を抽出
data = {
    'Alpha': [0.9, 0.99, 1.01, 1.02, 1.03, 1.1, 1.5, 2.0],
    'Mean_Z(t)': [df['Z'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]],
    'Std_Z(t)': [df['std'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]]
}

# 新しいデータフレームを作成
plot_df_w_05 = pd.DataFrame(data)

# %%
alpha09 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha1.02.csv")
alpha103 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha1.03.csv")
alpha11 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha1.5.csv")
alpha2 = pd.read_csv("data/Zt/N100_T100K_r10_omega0.0_alpha2.0.csv")

columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03", "alpha=1.1", "alpha=1.5", "alpha=2.0"]

# データフレームの結合
# 平均値のためのデータフレーム
mean_df = pd.concat([alpha09['t'], alpha09['Z'], alpha099['Z'], alpha101['Z'], alpha102['Z'], alpha103['Z'], alpha11['Z'], alpha15['Z'], alpha2['Z']], axis=1)
mean_df = mean_df[mean_df['t'] > 10]
mean_df.columns = columns

# display(mean_df)

# 標準偏差のためのデータフレーム
std_df = pd.concat([alpha09['t'], alpha09['std'], alpha099['std'], alpha101['std'], alpha102['std'], alpha103['std'], alpha11['std'], alpha15['std'], alpha2['std']], axis=1)
std_df = std_df[std_df['t'] > 10]
std_df.columns = columns

# 各データセットから最後の時刻の平均値と標準偏差を抽出
data = {
    'Alpha': [0.9, 0.99, 1.01, 1.02, 1.03, 1.1, 1.5, 2.0],
    'Mean_Z(t)': [df['Z'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]],
    'Std_Z(t)': [df['std'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]]
}

# 新しいデータフレームを作成
plot_df_w0 = pd.DataFrame(data)

# %%
alpha09 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha1.02.csv")
alpha103 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha1.03.csv")
alpha11 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha1.5.csv")
alpha2 = pd.read_csv("data/Zt/N100_T100K_r10_omega1.0_alpha2.0.csv")

columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03", "alpha=1.1", "alpha=1.5", "alpha=2.0"]
# columns = ["t", "alpha=0.9", "alpha=0.99", "alpha=1.01", "alpha=1.02", "alpha=1.03"]

# データフレームの結合
# 平均値のためのデータフレーム
mean_df = pd.concat([alpha09['t'], alpha09['Z'], alpha099['Z'], alpha101['Z'], alpha102['Z'], alpha103['Z'], alpha11['Z'], alpha15['Z'], alpha2['Z']], axis=1)
mean_df = mean_df[mean_df['t'] > 10]
mean_df.columns = columns

# display(mean_df)

# 標準偏差のためのデータフレーム
std_df = pd.concat([alpha09['t'], alpha09['std'], alpha099['std'], alpha101['std'], alpha102['std'], alpha103['std'], alpha11['std'], alpha15['std'], alpha2['std']], axis=1)
std_df = std_df[std_df['t'] > 10]
std_df.columns = columns

# 各データセットから最後の時刻の平均値と標準偏差を抽出
data = {
    'Alpha': [0.9, 0.99, 1.01, 1.02, 1.03, 1.1, 1.5, 2.0],
    'Mean_Z(t)': [df['Z'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]],
    'Std_Z(t)': [df['std'].iloc[-1] for df in [alpha09, alpha099, alpha101, alpha102, alpha103, alpha11, alpha15, alpha2]]
}

# 新しいデータフレームを作成
plot_df_w1 = pd.DataFrame(data)

# %%
# プロット作成
plt.figure(figsize=(8, 8))
plt.errorbar(plot_df_w_1['Alpha'], plot_df_w_1['Mean_Z(t)'], yerr=plot_df_w_1['Std_Z(t)'], fmt='o-', label='ω=-1.0')
plt.errorbar(plot_df_w_099['Alpha'], plot_df_w_099['Mean_Z(t)'], yerr=plot_df_w_099['Std_Z(t)'], fmt='o-', label='ω=-0.99')
plt.errorbar(plot_df_w_09['Alpha'], plot_df_w_09['Mean_Z(t)'], yerr=plot_df_w_09['Std_Z(t)'], fmt='o-', label='ω=-0.9')
plt.errorbar(plot_df_w_05['Alpha'], plot_df_w_05['Mean_Z(t)'], yerr=plot_df_w_05['Std_Z(t)'], fmt='o-', label='ω=-0.5')
plt.errorbar(plot_df_w0['Alpha'], plot_df_w0['Mean_Z(t)'], yerr=plot_df_w0['Std_Z(t)'], fmt='o-', label='ω=0.0')
plt.errorbar(plot_df_w1['Alpha'], plot_df_w1['Mean_Z(t)'], yerr=plot_df_w1['Std_Z(t)'], fmt='o-', label='ω=1.0')
plt.title("N=100, T=100K, r=100, Final Time Step Value of Z(t) for Each Alpha")
plt.xlabel('Alpha')
plt.ylabel('Z(t)')
plt.grid()
plt.legend()
plt.show()

# %%
# プロット作成
plt.figure(figsize=(8, 8))
plt.plot(plot_df_w_1['Alpha'], plot_df_w_1['Mean_Z(t)'], 'o-', label='ω=-1.0')
plt.plot(plot_df_w_099['Alpha'], plot_df_w_099['Mean_Z(t)'], 'o-', label='ω=-0.99')
plt.plot(plot_df_w_09['Alpha'], plot_df_w_09['Mean_Z(t)'], 'o-', label='ω=-0.9')
plt.plot(plot_df_w_05['Alpha'], plot_df_w_05['Mean_Z(t)'], 'o-', label='ω=-0.5')
plt.plot(plot_df_w0['Alpha'], plot_df_w0['Mean_Z(t)'], 'o-', label='ω=0.0')
plt.plot(plot_df_w1['Alpha'], plot_df_w1['Mean_Z(t)'], 'o-', label='ω=1.0')
plt.title("N=100, T=100K, r=100, Final Time Step Value of Z(t) for Each Alpha")
plt.xlabel('Alpha')
plt.ylabel('Z(t)')
plt.grid()
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# 平均値データフレームを "long format" に変換
mean_long = pd.melt(mean_df, id_vars=['t'], var_name='alpha', value_name='Z(t)')

# lineplot を作成（平均値）
plt.figure(figsize=(8, 6))
sns.lineplot(data=mean_long, x='t', y='Z(t)', hue='alpha', palette="tab10")

# 標準偏差の帯を追加
for column in mean_df.columns[1:]:
    alpha = column
    subset_mean = mean_df[['t', alpha]]
    subset_std = std_df[['t', alpha]]
    # plt.fill_between(subset_mean['t'], subset_mean[alpha] - subset_std[alpha], subset_mean[alpha] + subset_std[alpha], alpha=0.2)

plt.title("N=100, T=100K, r=10, ω=1.0")
plt.grid()
# 凡例をプロットエリアの外に設置
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylim(0.49, 0.6)
plt.show()
