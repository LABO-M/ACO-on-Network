# %%
# Networkモジュールをインポート
include("../src/sampling/network.jl")
# Out:
# Main.Network

# %%
# パラメータの設定
T = 10000
r = 100
w = -0.9

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = -0.99

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")

# %%
using CSV
using DataFrames

# パラメータの設定
T = 100
r = 3
w_list = [10, 1.0, 0, -0.99, -1.0]

for w in w_list
    # ネットワークの生成
    _, _, link_matrix = Network.generate_network(T, r, w)

    # マトリックスをDataFrameに変換
    df = DataFrame(link_matrix, :auto)

    # ファイル名の設定
    w_str = replace(string(w), ".0" => "")
    filename = "data/link/T100_omega$(w_str).csv"

    # CSVファイルに保存
    CSV.write(filename, df)
end

# %%
# パラメータの設定
T = 4
r = 3

k_in, k_out, link_matrix = Network.initialize_network(T, r)

link_matrix
# Out:
# 4×3 Matrix{Int64}:
#  0  0  0
#  1  0  0
#  1  2  0
#  1  2  3

# %%
# パラメータの設定
T = 6
r = 3
w = -1.0

k_in, k_out, link_matrix = Network.generate_network(T, r, w)

println("k_in = ", k_in)
println("k_out = ", k_out)
println("link_matrix = ", link_matrix)
# Out:
# k_in = [0, 1, 2, 3, 3, 3]
# k_out = [3, 3, 2, 1, 0, 0]
# link_matrix = [0 0 0; 1 0 0; 1 2 0; 1 2 3; 2 3 4; 3 4 5]

# %%
# パラメータの設定
T = 6
r = 3
w = 1.0

k_in, k_out, link_matrix = Network.generate_network(T, r, w)

println("k_in = ", k_in)
println("k_out = ", k_out)
println("link_matrix = ", link_matrix)
# Out:
# k_in = [0, 1, 2, 3, 3, 3]
# k_out = [3, 4, 3, 2, 0, 0]
# link_matrix = [0 0 0; 1 0 0; 1 2 0; 1 2 3; 2 3 4; 3 4 2]

# %%
# パラメータの設定
T = 6
r = 3
w = 0.0

k_in, k_out, link_matrix = Network.generate_network(T, r, w)

println("k_in = ", k_in)
println("k_out = ", k_out)
println("link_matrix = ", link_matrix)
# Out:
# k_in = [0, 1, 2, 3, 3, 3]
# k_out = [3, 4, 3, 2, 0, 0]
# link_matrix = [0 0 0; 1 0 0; 1 2 0; 1 2 3; 3 4 2; 4 3 2]

# %%
# パラメータの設定
T = 6
r = 3
w = -0.9

k_in, k_out, link_matrix = Network.generate_network(T, r, w)

println("k_in = ", k_in)
println("k_out = ", k_out)
println("link_matrix = ", link_matrix)
# Out:
# k_in = [0, 1, 2, 3, 2, 2]
# k_out = [3, 2, 3, 2, 0, 0]
# link_matrix = [0 0 0; 1 0 0; 1 2 0; 1 2 3; 4 3 0; 4 3 0]

# %%
# パラメータの設定
T = 10
r = 3
w = -0.99

k_in, k_out, link_matrix = Network.generate_network(T, r, w)

println("k_in = ", k_in)
println("k_out = ", k_out)
println("link_matrix = ", link_matrix)
# Out:
# k_in = [0, 1, 2, 3, 2, 3, 3, 3, 3, 3]
# k_out = [3, 2, 3, 4, 2, 3, 3, 2, 1, 0]
# link_matrix = [0 0 0; 1 0 0; 1 2 0; 1 2 3; 3 4 0; 4 5 3; 6 5 4; 7 6 4; 7 8 6; 9 8 7]

# %%
# パラメータの設定
T = 100000
r = 100
w = 10.0

_, k_out, _ = Network.generate_network(T, r, w)

# 散布図をプロット
using Plots
histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r = $(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = 1.0

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r = $(r), w = $(w)")

# %%
# パラメータの設定
T = 100000
r = 100
w = 0.0

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r = $(r), w = $(w)")

# %%
# パラメータの設定
T = 100000
r = 100
w = -0.99

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r = $(r), w = $(w)")

# %%
# パラメータの設定
T = 1000000
r = 100
w = -1.0

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r = $(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = 0.0

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = -1.0

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = -1.0

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = -0.9

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")

# %%
# パラメータの設定
T = 10000
r = 100
w = -0.99

_, k_out, _ = Network.generate_network(T, r, w)

# 次数分布をプロット
using Plots

histogram(k_out, bins=100, label="k_out", xlabel="k_out", ylabel="frequency", title="r =
$(r), w = $(w)")
