# %%
import sys
import os

# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display

sys.path.append(os.path.abspath("../src"))

from visuals.plots import *

# %%
# alpha_list = [0.9, 0.99, 1.01, 1.1, 1.5, 2.0]
# T = 100000 # 100K
# r = 100
# omega = -1.0

# for alpha in alpha_list:
#     command = f"julia ../src/sampling/main.jl --T {T} --r {r} --omega {omega} --alpha {alpha}"
#     os.system(command)
# Out:
# Running simulation with the following parameters:
# N = 100, T = 100K, r = 100, omega = -1.0, alpha = 0.9, samples = 10
# Samples: 100%|██████████████████████████████████████████| Time: 0:00:18:58:50
# Finished simulation
# Saved Zj values to data/Zj/N100_T100K_r100_omega-1.0_alpha0.9.csv
# Running simulation with the following parameters:
# N = 100, T = 100K, r = 100, omega = -1.0, alpha = 0.99, samples = 10
# Samples: 100%|██████████████████████████████████████████| Time: 0:00:18:22:39
# Finished simulation
# Saved Zj values to data/Zj/N100_T100K_r100_omega-1.0_alpha0.99.csv
# Running simulation with the following parameters:
# N = 100, T = 100K, r = 100, omega = -1.0, alpha = 1.01, samples = 10
# Samples: 100%|██████████████████████████████████████████| Time: 0:00:17:54:47
# Finished simulation
# Saved Zj values to data/Zj/N100_T100K_r100_omega-1.0_alpha1.01.csv
# Running simulation with the following parameters:
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

alpha09 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha1.02.csv")
# alpha103 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha1.03.csv")
alpha11 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha1.5.csv")
alpha20 = pd.read_csv("data/Zj/N100_T100K_r100_omega-1.0_alpha2.0.csv")

# %%
sns.histplot(alpha09["Zj"], bins=100)
# Out:
# <Axes: xlabel='Zj', ylabel='Count'>

# %%
sns.histplot(alpha099["Zj"], bins=100)
# Out:
# <Axes: xlabel='Zj', ylabel='Count'>

# %%
sns.histplot(alpha101["Zj"], bins=100)
# Out:
# <Axes: xlabel='Zj', ylabel='Count'>

# %%
sns.histplot(alpha11["Zj"], bins=100)
# Out:
# <Axes: xlabel='Zj', ylabel='Count'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

alpha09 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha1.02.csv")
alpha11 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha1.5.csv")
alpha20 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.99_alpha2.0.csv")

# %%
sns.histplot(alpha09["Zj"], bins=100)
plt.title("alpha=0.9")
plt.show()
sns.histplot(alpha099["Zj"], bins=100)
plt.title("alpha=0.99")
plt.show()
sns.histplot(alpha101["Zj"], bins=100)
plt.title("alpha=1.01")
plt.show()
sns.histplot(alpha102["Zj"], bins=100)
plt.title("alpha=1.02")
plt.show()
sns.histplot(alpha11["Zj"], bins=100)
plt.title("alpha=1.1")
plt.show()
sns.histplot(alpha15["Zj"], bins=100)
plt.title("alpha=1.5")
plt.show()
sns.histplot(alpha20["Zj"], bins=100)
plt.title("alpha=2.0")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

alpha09 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha0.9.csv")
alpha099 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha0.99.csv")
alpha101 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha1.01.csv")
alpha102 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha1.02.csv")
alpha11 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha1.1.csv")
alpha15 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha1.5.csv")
alpha20 = pd.read_csv("data/Zj/N100_T100K_r100_omega-0.9_alpha2.0.csv")

# %%
sns.histplot(alpha09["Zj"], bins=100)
plt.title("alpha=0.9")
plt.show()
sns.histplot(alpha099["Zj"], bins=100)
plt.title("alpha=0.99")
plt.show()
sns.histplot(alpha101["Zj"], bins=100)
plt.title("alpha=1.01")
plt.show()
sns.histplot(alpha102["Zj"], bins=100)
plt.title("alpha=1.02")
plt.show()
sns.histplot(alpha11["Zj"], bins=100)
plt.title("alpha=1.1")
plt.show()
sns.histplot(alpha15["Zj"], bins=100)
plt.title("alpha=1.5")
plt.show()
sns.histplot(alpha20["Zj"], bins=100)
plt.title("alpha=2.0")
plt.show()
